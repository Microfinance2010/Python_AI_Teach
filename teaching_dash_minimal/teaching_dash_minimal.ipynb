# %% [markdown]
# # AI Product Mini-Projekt
#
# - Laden Finanz-Daten für beliebige Firmen über SEC-API
# - Berechne Bewertungsmultiples
# - Stelle sie dar über eine Dash-GUI
# - Ermögliche das Stellen von Fragen über LLM
# - Binde bei Beantwortung 10-K Filings über RAG ein

# %% [markdown]
# ## Setup

# %% [markdown]
# ## Architektur des Mini-Projekts
#
# Dieses Notebook ist bewusst in drei Ebenen getrennt:
#
# 1. `main_api` liefert generische SEC-API-Funktionen und kann auch in anderen Projekten wiederverwendet werden.
# 2. `teaching_dash_minimal_utils.py` enthaelt notebook-spezifische Hilfsfunktionen wie Filing-Download, Text-Extraktion und Kennzahlen-Loading.
# 3. Das Notebook selbst zeigt nur die Orchestrierung: Konfiguration, Beispielabfragen, RAG-Logik und Dash-Oberflaeche.
#
# Dadurch bleibt das Notebook lesbar, waehrend die eigentliche Implementierung in Python-Dateien gepflegt wird.

# %%
# Falls noetig, einmalig ausfuehren:
# %pip install -r requirements.txt

import os
import pandas as pd
# Library zum Erstellen von Grafiken
import plotly.express as px
import plotly.graph_objects as go
# Library zum Erstellen von Web-Dashboards
from dash import Dash, dcc, html, Input, Output, State
# Library zum Abrufen von Finanzdaten
import requests
from getpass import getpass

try:
    import teaching_dash_minimal_utils
except ModuleNotFoundError as exc:
    raise ModuleNotFoundError(
        "teaching_dash_minimal_utils.py oder main_api.py wurde nicht gefunden. "
        "Bitte Notebook, teaching_dash_minimal_utils.py und main_api.py im selben Ordner bereitstellen "
        "oder das Projekt ueber start_notebook_env.sh starten."
    ) from exc
# Out:
# Collecting git+https://github.com/Microfinance2010/main_api.git@v0.1.0 (from -r requirements.txt (line 11))
#   Cloning https://github.com/Microfinance2010/main_api.git (to revision v0.1.0) to /private/var/folders/00/ypkctdfn4vnfskp086yxk5fc0000gp/T/pip-req-build-2zd5skgg
#   Running command git clone --filter=blob:none --quiet https://github.com/Microfinance2010/main_api.git /private/var/folders/00/ypkctdfn4vnfskp086yxk5fc0000gp/T/pip-req-build-2zd5skgg
#   Resolved https://github.com/Microfinance2010/main_api.git to commit 28d573cd71fffe073907429612df87dceebe3402
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (4.14.3)
# Requirement already satisfied: ipykernel in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (7.2.0)
# Collecting jupyterlab (from -r requirements.txt (line 3))
#   Using cached jupyterlab-4.5.6-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: plotly in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (6.6.0)
# Requirement already satisfied: dash in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: requests in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (2.32.5)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from beautifulsoup4->-r requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from beautifulsoup4->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (9.11.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: psutil>=5.7 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 2)) (5.14.3)
# Collecting async-lru>=1.0.0 (from jupyterlab->-r requirements.txt (line 3))
#   Using cached async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting httpx<1,>=0.25.0 (from jupyterlab->-r requirements.txt (line 3))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 3)) (3.1.6)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->-r requirements.txt (line 3))
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->-r requirements.txt (line 3))
#   Using cached jupyter_server-2.17.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->-r requirements.txt (line 3))
#   Using cached jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->-r requirements.txt (line 3))
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jupyterlab->-r requirements.txt (line 3)) (82.0.1)
# Collecting anyio (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: certifi in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 3)) (2026.2.25)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 3)) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached jupyter_server_terminals-0.5.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (5.10.4)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Downloading prometheus_client-0.25.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached send2trash-2.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached babel-2.18.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 3))
#   Downloading json5-0.14.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 3)) (4.26.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 4)) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from plotly->-r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from dash->-r requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: Werkzeug<3.2 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from dash->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: importlib-metadata in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from dash->-r requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: retrying in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from dash->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: blinker>=1.9.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash->-r requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 7)) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 7)) (2.6.3)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached argon2_cffi_bindings-25.1.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Requirement already satisfied: decorator>=5.1.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: pexpect>4.6 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 3)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r requirements.txt (line 2)) (4.9.4)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Downloading python_json_logger-4.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting rfc3987-syntax>=1.1.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: bleach!=5.0.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 4)) (1.17.0)
# Collecting lark>=1.2.2 (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3)) (3.0)
# Requirement already satisfied: zipp>=3.20 in /Users/jonasvogt/Job/Vorlesungen/Python/Python_AI_Teach/.venv/lib/python3.13/site-packages (from importlib-metadata->dash->-r requirements.txt (line 6)) (3.23.0)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Using cached arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting tzdata (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 3))
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Using cached jupyterlab-4.5.6-py3-none-any.whl (12.4 MB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jupyter_server-2.17.0-py3-none-any.whl (388 kB)
# Using cached jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Using cached async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Using cached babel-2.18.0-py3-none-any.whl (10.2 MB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading json5-0.14.0-py3-none-any.whl (36 kB)
# Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
# Using cached jupyter_server_terminals-0.5.4-py3-none-any.whl (13 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading prometheus_client-0.25.0-py3-none-any.whl (64 kB)
# Downloading python_json_logger-4.1.0-py3-none-any.whl (15 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Using cached lark-1.3.1-py3-none-any.whl (113 kB)
# Using cached send2trash-2.1.0-py3-none-any.whl (17 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached webcolors-25.10.0-py3-none-any.whl (14 kB)
# Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Using cached argon2_cffi_bindings-25.1.0-cp39-abi3-macosx_11_0_arm64.whl (31 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.4.0-py3-none-any.whl (68 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: main-api
#   Building wheel for main-api (pyproject.toml) ... done
#   Created wheel for main-api: filename=main_api-0.1.0-py3-none-any.whl size=13842 sha256=50e1ca50d03baf6edc49dd33a2b41844ea9657c2fa2e96c1c8023263d7e8847a
#   Stored in directory: /private/var/folders/00/ypkctdfn4vnfskp086yxk5fc0000gp/T/pip-ephem-wheel-cache-ytet2nf0/wheels/68/04/8a/da5c2facb0fd31b3d92cc1b2dd9f2fbfb541a027d2aa102d42
# Successfully built main-api
# Installing collected packages: websocket-client, webcolors, uri-template, tzdata, terminado, send2trash, rfc3986-validator, rfc3339-validator, pyyaml, python-json-logger, prometheus-client, lark, jsonpointer, json5, h11, fqdn, babel, async-lru, anyio, rfc3987-syntax, jupyter-server-terminals, httpcore, arrow, argon2-cffi-bindings, main-api, isoduration, httpx, argon2-cffi, jupyter-events, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab
#   Attempting uninstall: main-api91m╸━━━━━━━━━━━━━━━━━━━━━ 16/34 [babel]
#     Found existing installation: main-api 0.1.0━━━━━━━━━━━━━━━ 16/34 [babel]
#     Uninstalling main-api-0.1.0:━━━━━━━━━━━━━━━━━━━━━ 16/34 [babel]
#       Successfully uninstalled main-api-0.1.0╺━━━━━━━━━━━ 24/34 [main-api]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [jupyterlab]4 [jupyterlab]ver]
# Successfully installed anyio-4.13.0 argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.4.0 async-lru-2.3.0 babel-2.18.0 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 isoduration-20.11.0 json5-0.14.0 jsonpointer-3.1.1 jupyter-events-0.12.0 jupyter-lsp-2.3.1 jupyter-server-2.17.0 jupyter-server-terminals-0.5.4 jupyterlab-4.5.6 jupyterlab-server-2.28.0 lark-1.3.1 main-api-0.1.0 notebook-shim-0.2.4 prometheus-client-0.25.0 python-json-logger-4.1.0 pyyaml-6.0.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 send2trash-2.1.0 terminado-0.18.1 tzdata-2026.1 uri-template-1.3.0 webcolors-25.10.0 websocket-client-1.9.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Die Utilities wurden in die Datei `teaching_dash_minimal_utils.py` ausgelagert.
#
# Die folgende Zelle importiert diese Hilfsfunktionen fuer das Notebook. Bitte fuehren Sie sie aus, auch wenn wir ihren Inhalt nicht weiter besprechen.
#
# Wichtige Beispiele aus dem Modul sind:
#
# ```python
# load_three_metrics(cik: int, start_year: int, end_year: int) -> pd.DataFrame
# FilingDownloader(...)
# extract_clean_10k_text(filing_paths: dict, min_chars: int) -> tuple[str, str]
# ```

# %%
# %%capture

from teaching_dash_minimal_utils import (
    SEC_HEADERS,
    FilingDownloader,
    _build_openrouter_url,
    extract_clean_10k_text,
    load_three_metrics,
)

# %%
# Konfiguration
BIG_TECH = {
    "Apple": 320193,
    "Microsoft": 789019,
    "Alphabet": 1652044,
    "Amazon": 1018724,
    "Meta": 1326801,
    "NVIDIA": 1045810,
    "Tesla": 1318605,
}


# Email fuer EDGAR API, damit die Anfragen nicht blockiert werden
SEC_USER_AGENT = "EdinDzeko@Goal.com"
SEC_HEADERS["User-Agent"] = SEC_USER_AGENT


metrics_df = load_three_metrics(BIG_TECH["Meta"], start_year=2001, end_year=2024)
metrics_df
# Out:
#     year            metric         value  form                      mode
# 0   2001  diluted_earnings           NaN  10-K                    direct
# 1   2001             capex           NaN  10-K            normalized_abs
# 2   2001               fcf           NaN  10-K  direct_from_companyfacts
# 3   2002  diluted_earnings           NaN  10-K                    direct
# 4   2002             capex           NaN  10-K            normalized_abs
# ..   ...               ...           ...   ...                       ...
# 67  2023             capex  2.726600e+10  10-K            normalized_abs
# 68  2023               fcf  4.384700e+10  10-K  direct_from_companyfacts
# 69  2024  diluted_earnings  2.386000e+01  10-K                    direct
# 70  2024             capex  3.725600e+10  10-K            normalized_abs
# 71  2024               fcf  5.407200e+10  10-K  direct_from_companyfacts
#
# [72 rows x 5 columns]

# %% [markdown]
# ## LLM-Funktion
#
# Default: Cloud-Free-Tier ueber OpenRouter. Erstellen Sie einen kostenlosen API-Key dafür im Netz. Alternativ: Eigener Open-AI-Key für leistungsfährigere Modelle.

# %%
import os
openrouter_api_key = os.getenv("OPENROUTER_API_KEY")
if not openrouter_api_key:
    print("Bitte setzen Sie die Variable OPENROUTER_API_KEY mit Ihrem OpenRouter API-Schlüssel.")
    os.environ["OPENROUTER_API_KEY"] = getpass("OpenRouter API Key eingeben (wird nicht angezeigt): ")

# %%
def ask_llm(question: str, context: str = "") -> str:
    """Cloud-Free-Tier ueber OpenRouter."""
    api_key = os.getenv("OPENROUTER_API_KEY", "")
    if not api_key:
        return "Kein OPENROUTER_API_KEY gesetzt."

    url = _build_openrouter_url()
    model = os.getenv("OPENROUTER_MODEL", "openrouter/auto")

    prompt = f"Kontext:\n{context}\n\nFrage: {question}\nAntworte kurz und klar."

    try:
        r = requests.post(
            url,
            headers={
                "Authorization": f"Bearer {api_key}",
                "Content-Type": "application/json",
                # Empfohlen von OpenRouter, hilft bei einigen Setups.
                "HTTP-Referer": os.getenv("OPENROUTER_SITE_URL", "http://localhost"),
                "X-Title": os.getenv("OPENROUTER_APP_NAME", "SEC Teaching Notebook"),
            },
            json={
                "model": model,
                "messages": [{"role": "user", "content": prompt}],
                "temperature": 0,
            },
            timeout=120,
        )

        if r.status_code >= 400:
            # Detailierte Antwort hilft bei 404/401-Diagnose direkt im Notebook.
            body = r.text[:500]
            if r.status_code == 404:
                return (
                    f"LLM-API Fehler 404: Endpoint oder Modell nicht gefunden. "
                    f"URL={url}, model={model}, body={body}"
                )
            return f"LLM-API Fehler {r.status_code}: {body}"

        data = r.json()
        return data.get("choices", [{}])[0].get("message", {}).get("content", "Keine Antwort erhalten.")
    except Exception as e:
        return f"LLM-API Fehler: {e}"

# %% [markdown]
# ## RAG für letzte 2x 10-K Filings
#
# Dieser Abschnitt baut den Retrieval-Kontext aus den letzten zwei verfuegbaren 10-K Filings direkt ueber die SEC-API auf.
#
# 1. Frage wird in Tokens zerlegt (q_tokens), z. B. Wörter wie „cash“, „flow“, „meta“.
# 2. Die letzten 2 passenden 10-K Filings werden über SEC geholt.
# 3. Aus jedem Filing wird der Text extrahiert.
# 4. Der Text wird in kleinere Abschnitte (Chunks) geteilt.
# 5. Jeder Chunk wird ebenfalls in Tokens zerlegt (c_tokens).
# 6. Pro Chunk wird ein einfacher Relevanz-Score berechnet:
# ```python
# len(q_tokens.intersection(c_tokens))
# ```
# Es wird gezählt, wie viele verschiedene Wörter in Frage und Chunk gleichzeitig vorkommen. Das ist eine sehr einfache Relevanz-Quantifizierung. Alternativen würden z.B. die Distanz zwischen dem Durchschnitt aus Embedding-Vektoren über alle Token in Query und einzelnen Chunks berechnen.
#
# 7. Die Top-k Chunks mit dem höchsten Score werden ausgewählt.
# Diese Chunks werden als RAG-Kontext an das LLM gegeben.

# %%
import re
import requests
from bs4 import BeautifulSoup



def _normalize_text(s: str) -> str:
    return re.sub(r"[^a-z0-9]", "", (s or "").lower())


def _tokenize_for_rag(text: str) -> set[str]:
    tokens = re.findall(r"[a-zA-Z0-9]{3,}", (text or "").lower())
    stopwords = {
        "the", "and", "for", "with", "from", "that", "this", "are", "was", "were", "have", "has",
        "ein", "eine", "und", "der", "die", "das", "ist", "mit", "von", "auf", "wie", "sind",
        "what", "when", "where", "which", "uber", "into", "also", "their", "its", "our",
    }
    return {t for t in tokens if t not in stopwords}


def _clean_whitespace(s: str) -> str:
    return re.sub(r"\s+", " ", (s or "")).strip()


def _html_to_text(html: str) -> str:
    soup = BeautifulSoup(html or "", "html.parser")
    for tag in soup(["script", "style", "noscript"]):
        tag.decompose()
    return _clean_whitespace(soup.get_text(" "))


def _extract_10k_text_from_submission_raw(raw_submission: str) -> str:
    docs = (raw_submission or "").split("<DOCUMENT>")
    best_text = ""

    for d in docs[1:]:
        m_type = re.search(r"<TYPE>\s*([^\s<]+)", d)
        doc_type = (m_type.group(1).strip().upper() if m_type else "")

        if doc_type in {"10-K", "10K"}:
            m_text = re.search(r"<TEXT>(.*)</TEXT>", d, flags=re.DOTALL | re.IGNORECASE)
            if not m_text:
                continue
            content = m_text.group(1)

            if "<html" in content.lower() or "<table" in content.lower():
                cand = _html_to_text(content)
            else:
                cand = _clean_whitespace(content)

            if len(cand) > len(best_text):
                best_text = cand

    return best_text


def _fetch_complete_submission_text(cik: int, accession_number: str, headers: dict) -> str:
    accession_no_nodashes = accession_number.replace("-", "")
    url = f"https://www.sec.gov/Archives/edgar/data/{cik}/{accession_no_nodashes}/{accession_number}.txt"
    r = requests.get(url, headers=headers, timeout=120)
    r.raise_for_status()
    return r.text


def _find_latest_two_10k_filings_api(company_name: str) -> list[dict]:
    cik = BIG_TECH[company_name]
    downloader = FilingDownloader(download_dir="./downloads", user_agent=SEC_USER_AGENT)

    submissions = downloader.get_all_submissions(cik)
    recent = submissions.get("filings", {}).get("recent", {})

    forms = recent.get("form", [])
    filing_dates = recent.get("filingDate", [])
    accession_numbers = recent.get("accessionNumber", [])
    fiscal_years = recent.get("fiscalYear", [])
    report_dates = recent.get("reportDate", [])

    candidates = []
    for i, form in enumerate(forms):
        if form not in {"10-K", "10-K/A"}:
            continue

        fy = None
        if fiscal_years and i < len(fiscal_years) and fiscal_years[i]:
            fy = int(fiscal_years[i])
        elif report_dates and i < len(report_dates) and report_dates[i]:
            fy = int(str(report_dates[i])[:4])

        candidates.append({
            "fiscal_year": fy if fy is not None else 0,
            "filing_date": filing_dates[i] if i < len(filing_dates) else "",
            "accession_number": accession_numbers[i] if i < len(accession_numbers) else "",
            "cik": cik,
            "headers": downloader.headers,
        })

    candidates = [c for c in candidates if c["accession_number"]]

    unique_by_year = {}
    for c in sorted(candidates, key=lambda x: x["filing_date"], reverse=True):
        fy = c["fiscal_year"]
        if fy not in unique_by_year:
            unique_by_year[fy] = c

    latest = sorted(unique_by_year.values(), key=lambda x: x["fiscal_year"], reverse=True)[:2]
    return latest


def _chunk_text(text: str, chunk_size: int = 1400, overlap: int = 250) -> list[str]:
    text = (text or "").strip()
    if not text:
        return []

    chunks = []
    start = 0
    n = len(text)
    step = max(1, chunk_size - overlap)
    while start < n:
        end = min(n, start + chunk_size)
        chunks.append(text[start:end])
        if end >= n:
            break
        start += step
    return chunks


def build_10k_rag_context(company_name: str, question: str, top_k: int = 4) -> tuple[str, list[str]]:
    filings = _find_latest_two_10k_filings_api(company_name)
    if not filings:
        return "", []

    q_tokens = _tokenize_for_rag(question)
    scored_chunks = []
    used_sources = []

    for filing in filings:
        try:
            raw = _fetch_complete_submission_text(
                cik=filing["cik"],
                accession_number=filing["accession_number"],
                headers=filing["headers"],
            )
            txt = _extract_10k_text_from_submission_raw(raw)
        except Exception:
            continue

        if not txt:
            continue

        src = f"FY{filing['fiscal_year']} ({filing['filing_date']})"
        used_sources.append(src)

        for ch in _chunk_text(txt):
            c_tokens = _tokenize_for_rag(ch)
            score = len(q_tokens.intersection(c_tokens)) if q_tokens else 0
            scored_chunks.append((score, src, ch))

    if not scored_chunks:
        return "", used_sources

    scored_chunks.sort(key=lambda x: x[0], reverse=True)
    selected = scored_chunks[:top_k]

    parts = []
    for i, (_, src, ch) in enumerate(selected, start=1):
        snippet = ch[:1200].replace("\n", " ").strip()
        parts.append(f"[{i}] Quelle={src} | Auszug: {snippet}")

    return "\n\n".join(parts), used_sources

# %% [markdown]
# ## Query an LLM mit RAG und Übergabe konkreter Daten

# %%
company_name = "Meta"
# Query des Nutzers
question = "Wie haben sich aus welchen Gründen die CAPEX entwickelt?"

# Abfrage der Rohdaten und Berechnen der Bewertungsmultuples
df = load_three_metrics(BIG_TECH[company_name], 2020, 2024)
metrics_ctx = df.pivot_table(index="year", columns="metric", values="value", aggfunc="first").reset_index().to_string(index=False)

# Abfrage der Unternehmensreports und Berechnen der RAG Scores
rag_ctx, sources = build_10k_rag_context(company_name=company_name, question=question)

# Aufbauen des zusätzlichen Kontextes (neben der Query) für die LLM-Abfrage
combined_ctx = f"Unternehmen: {company_name}\n\nMetriken:\n{metrics_ctx}\n\nRAG Kontext:\n{rag_ctx}"

# Anfrage an das LLM mit dem gesamten (kombinierten) Kontext
answer = ask_llm(question, context=combined_ctx)
print(answer)
# Out:
# Lade Submissions für CIK 0001326801...
# Lade 2 zusätzliche Filing-Archive...
# Die CAPEX von Meta sind von 2020 bis 2024 stark gestiegen, mit einem deutlichen Sprung im Jahr 2022. Dies ist wahrscheinlich auf die massiven Investitionen in das Metaverse und die Infrastruktur zurückzuführen.

# %% [markdown]
# ## Mini Dash Ansicht

# %%
app = Dash(__name__)

app.layout = html.Div([
    html.H3("SEC Teaching Mini App"),
    html.Div([
        dcc.Dropdown(
            id="company_dd",
            options=[{"label": name, "value": name} for name in BIG_TECH.keys()],
            value= list(BIG_TECH.keys())[0],
            clearable=False,
            style={"width": "260px"},
        ),
        dcc.Dropdown(
            id="metric_dd",
            options=[
                {"label": "Diluted Earnings", "value": "diluted_earnings"},
                {"label": "CAPEX", "value": "capex"},
                {"label": "FCF", "value": "fcf"},
            ],
            value="fcf",
            clearable=False,
            style={"width": "220px"},
        ),
    ], style={"display": "flex", "gap": "12px", "marginBottom": "10px"}),
    dcc.Graph(id="line_fig"),
    html.Div(id="simple_label", style={"marginTop": "8px", "marginBottom": "12px"}),
    dcc.Textarea(id="chat_input", placeholder="Frage z. B.: Wie ist der FCF?", style={"width": "100%", "height": "80px"}),
    html.Button("Senden", id="send_btn", n_clicks=0, style={"marginTop": "8px"}),
    html.Div(id="chat_output", style={"marginTop": "10px", "padding": "10px", "backgroundColor": "#f6f8fa"}),
])

@app.callback(
    Output("line_fig", "figure"),
    Output("simple_label", "children"),
    Input("company_dd", "value"),
    Input("metric_dd", "value"),
)
def update_chart(company_name, metric):
    df = load_three_metrics(BIG_TECH[company_name], 2020, 2024)
    d = df[df["metric"] == metric].sort_values("year")
    fig = px.line(d, x="year", y="value", markers=True, title=f"{company_name}: {metric} pro Jahr")
    latest = d.iloc[-1]["value"] if not d.empty else None
    label = f"{company_name}: kein aktueller Wert" if latest is None or pd.isna(latest) else f"{company_name}: {metric} aktuell {'positiv' if latest > 0 else 'nicht positiv'}"
    return fig, label

@app.callback(
    Output("chat_output", "children"),
    Input("send_btn", "n_clicks"),
    State("chat_input", "value"),
    State("company_dd", "value"),
)
def update_chat(n_clicks, question, company_name):
    if not n_clicks:
        return "Noch keine Frage gestellt."

    df = load_three_metrics(BIG_TECH[company_name], 2020, 2024)
    metrics_ctx = df.pivot_table(index="year", columns="metric", values="value", aggfunc="first").reset_index().to_string(index=False)

    rag_ctx, sources = build_10k_rag_context(company_name=company_name, question=question or "")
    combined_ctx = f"Unternehmen: {company_name}\n\nMetriken:\n{metrics_ctx}"
    if rag_ctx:
        combined_ctx += f"\n\nRAG (letzte 2x 10-K):\n{rag_ctx}"

    try:
        answer = ask_llm(question or "", context=combined_ctx)
    except Exception as e:
        answer = f"LLM-Fehler: {e}"

    if sources:
        src_text = "Quellen (RAG): " + ", ".join(sources)
    else:
        src_text = "Quellen (RAG): keine 10-K Dateien gefunden"

    return [html.B("Antwort: "), answer, html.Br(), html.Small(src_text)]

# %%
# App im Notebook starten
app.run(jupyter_mode="inline", debug=False, port=8056)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8056/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Lade Submissions für CIK 0000320193...
# Lade 1 zusätzliche Filing-Archive...
